# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshikakhandelwall/DATA-ANALYTICS-ASSIGNMENTS-/blob/main/Module3_Activity3_1_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3 – Activity 3.1
# ## Pandas Hands-on Lab (5 Marks)
#
# **Instructions:**
# - Complete all tasks
# - Write code in the given cells
# - Run each cell and show outputs
# - Add comments wherever required
# - Submit the completed notebook (PDF) on LMS
#
# **Name:** __ANSHIKA KHANDELWAL__________
# **Roll No.:** _BETN1AI25001___________
# **Course:** Data Analytics Using Python (AIL0202)
#
# collab link :https://colab.research.google.com/drive/1Rxdaidc23uH7ExKlft7kbQ9hQodyYob3#scrollTo=t87JzGflhXZD

# %%
# Import required libraries
# Write code to import pandas and numpy

# %% [markdown]
# ## Task 1: Data Creation & Loading (1 Mark)
# Dataset:
#     'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
#     'Department': ['IT','HR','IT','Finance','HR'],
#     'Salary': [50000,60000,55000,65000,52000]

# %%
# Create:
import pandas as pd

# 1. A Pandas Series from a list of 5 elements
data_list = [10, 20, 30, 40, 50]
series = pd.Series(data_list)
print("Pandas Series:\n", series)

# 2. A DataFrame with columns: Name, Department, Salary

data = {
    'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': [50000,60000,55000,65000,52000]
}

df = pd.DataFrame(data)
print("\nDataFrame:\n", df)
print("\n")


# 3. Write a dataset using (any one): CSV / Excel / JSON
print("dataset using excel file \n")

df=pd.read_csv("/content/Book1.csv")
print(df)
# Out:
# Pandas Series:
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# DataFrame:
#      Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 3  Sneha    Finance   65000
# 4  Karan         HR   52000
#
#
# dataset using excel file
#
#    name      dept  salary
# 0  Aman        IT   50000
# 1   Riya       HR   60000
# 2  Rahul       IT   55000
# 3  Sneha  FINANCE   65000
# 4  Karan       HR   52000

# %% [markdown]
# ## Task 2: Data Exploration (1 Mark)

# %%
# Perform:
# Display first 3 rows

print("first 3 rows are :\n")
print(df.head(3))
print("\n")

# Display dataset information

print("dataset information is :\n")
print(df.info())
print("\n")

# Display statistical summary

print("statistical summary of data is :\n")
print(df.describe())
# Out:
# first 3 rows are :
#
#    name  dept  salary
# 0  Aman    IT   50000
# 1   Riya   HR   60000
# 2  Rahul   IT   55000
#
#
# dataset information is :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   dept    5 non-null      object
#  2   salary  5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None
#
#
# statistical summary of data is :
#
#              salary
# count      5.000000
# mean   56400.000000
# std     6107.372594
# min    50000.000000
# 25%    52000.000000
# 50%    55000.000000
# 75%    60000.000000
# max    65000.000000

# %% [markdown]
# ## Task 3: Indexing, Filtering & Sorting (1 Mark)

# %%
# Perform:
# 1. Extract first 3 rows using .loc[]

print("first 3 rows using .loc \n")
print(df.loc[0:2])
print("\n")

# 2. Extract Salary column using .iloc[]
print("salary column using iloc \n")
salary=df.iloc[:,2]
print(salary)
print("\n")

# 3. Filter employees with Salary > 55000

print("filter employees with salary >55000 \n")

filtered_df = df[df['salary'] > 55000]
print(filtered_df)
print("\n")

# 4. Sort dataset by Salary (descending)

print("sorted dataset \n")
sorted_df = df.sort_values(by='salary', ascending=False)
print(sorted_df)
# Out:
# first 3 rows using .loc
#
#    name  dept  salary
# 0  Aman    IT   50000
# 1   Riya   HR   60000
# 2  Rahul   IT   55000
#
#
# salary column using iloc
#
# 0    50000
# 1    60000
# 2    55000
# 3    65000
# 4    52000
# Name: salary, dtype: int64
#
#
# filter employees with salary >55000
#
#    name      dept  salary
# 1   Riya       HR   60000
# 3  Sneha  FINANCE   65000
#
#
# sorted dataset
#
#    name      dept  salary
# 3  Sneha  FINANCE   65000
# 1   Riya       HR   60000
# 2  Rahul       IT   55000
# 4  Karan       HR   52000
# 0  Aman        IT   50000

# %% [markdown]
# ## Task 4: Group-by & Aggregation (1 Mark)

# %%
# Perform:
# 1. Find average salary department-wise

print("average salary :\n")
avg_salary = df.groupby('dept')['salary'].mean()
print(avg_salary)
print("\n")

# 2. Find total and count of employees per department

print("total and count of employees per department:\n")
result = df.groupby('dept')['salary'].agg(['sum', 'count'])
print(result)
# Out:
# average salary :
#
# dept
# FINANCE    65000.0
# HR         56000.0
# IT         52500.0
# Name: salary, dtype: float64
#
#
# total and count of employees per department:
#
#             sum  count
# dept
# FINANCE   65000      1
# HR       112000      2
# IT       105000      2

# %% [markdown]
# ## Task 5: Data Cleaning & Time-Series (1 Mark)

# %%
# Given:
# df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']

# Perform:
# 1. Convert Joining_Date to datetime

# Add Joining_Date column
df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']

# Convert to datetime
df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])

print(df)
print("\n")

# 2. Extract Year and Month

print("year and month:\n")

df['Year'] = df['Joining_Date'].dt.year
df['Month'] = df['Joining_Date'].dt.month

print(df)
print("\n")

# 3. Identify duplicate rows

print( "Identify duplicate rows\n")
duplicates = df[df.duplicated()]
print(duplicates)
print("\n")

# 4. Remove duplicate rows

print("Remove duplicate rows\n")
df_remove = df.drop_duplicates()
print(df_remove)
# Out:
#    name      dept  salary Joining_Date  Year  Month
# 0  Aman        IT   50000   2022-01-10  2022      1
# 1   Riya       HR   60000   2021-07-15  2021      7
# 2  Rahul       IT   55000   2023-03-12  2023      3
# 3  Sneha  FINANCE   65000   2020-11-05  2020     11
# 4  Karan       HR   52000   2022-05-20  2022      5
#
#
# year and month:
#
#    name      dept  salary Joining_Date  Year  Month
# 0  Aman        IT   50000   2022-01-10  2022      1
# 1   Riya       HR   60000   2021-07-15  2021      7
# 2  Rahul       IT   55000   2023-03-12  2023      3
# 3  Sneha  FINANCE   65000   2020-11-05  2020     11
# 4  Karan       HR   52000   2022-05-20  2022      5
#
#
# Identify duplicate rows
#
# Empty DataFrame
# Columns: [name , dept, salary, Joining_Date, Year, Month]
# Index: []
#
#
# Remove duplicate rows
#
#    name      dept  salary Joining_Date  Year  Month
# 0  Aman        IT   50000   2022-01-10  2022      1
# 1   Riya       HR   60000   2021-07-15  2021      7
# 2  Rahul       IT   55000   2023-03-12  2023      3
# 3  Sneha  FINANCE   65000   2020-11-05  2020     11
# 4  Karan       HR   52000   2022-05-20  2022      5
